# %% [markdown]
# # Lab 16 - Customer Analysis (Activity 5)

# %% [markdown]
# ## Activity 1

# %% [markdown]
# **Aggregate data into one Data Frame using Pandas.**

# %%
import pandas as pd
print(pd.__version__)

insurance_df = pd.read_csv('/Users/Annie/Documents/GitHub/IronAnne/Labs/Pandas/file1.csv')
print(insurance_df)

insurance_df_two = pd.read_csv('/Users/Annie/Documents/GitHub/IronAnne/Labs/Pandas/file2.csv')
print(insurance_df_two)

#Are they the same? If no, then move on 
print(pd.DataFrame.equals(insurance_df, insurance_df_two))

#Check if columns are the same?
    #sometimes you have to rearrange columns, but Pandas is recognizing them automatically
print(insurance_df.columns)
print(insurance_df_two.columns)

insurance_df_all = pd.concat([insurance_df, insurance_df_two], axis=0, ignore_index=True)
print(insurance_df_all)
# Out:
# 1.2.4
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]
# False
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4999              847141.75%  63513.0                  70.0
# 5000              543121.91%  58161.0                  68.0
# 5001              568964.41%  83640.0                  70.0
# 5002              368672.38%      0.0                  96.0
# 5003              399258.39%      0.0                 111.0
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4999                    1/0/00   Personal Auto  Four-Door Car
# 5000                    1/0/00  Corporate Auto  Four-Door Car
# 5001                    1/0/00  Corporate Auto   Two-Door Car
# 5002                    1/0/00   Personal Auto   Two-Door Car
# 5003                    1/0/00   Personal Auto            SUV
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4999          185.667213
# 5000          140.747286
# 5001          471.050488
# 5002           28.460568
# 5003          700.349052
#
# [5004 rows x 11 columns]

# %% [markdown]
# **Standardizing header names**

# %%
#2.2. Standardizing header names
    # display the dataframe head
print(insurance_df_all.head(10))

#2.2.1. Convert column header to string
#df.columns = df.columns.astype("str")

#2.2.2. Format column header with cases
    #Index.str method
    #df.columns = df.columns.str.upper()
insurance_df_all.columns = insurance_df_all.columns.str.lower()
print(insurance_df_all)

###2.2.3. Rename columns

insurance_df_all_new = insurance_df_all.rename(columns = {'st': 'state'}, inplace = False)
print(insurance_df_all_new)
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
# 6  XZ87318      Oregon      F               College              538089.86%
# 7  CF85061     Arizona      M                Master              721610.03%
# 8  DY87989      Oregon      M              Bachelor             2412750.40%
# 9  BQ94931      Oregon      F               College              738817.81%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
# 5  62902.0                  69.0                    1/0/00   Personal Auto
# 6  55350.0                  67.0                    1/0/00  Corporate Auto
# 7      0.0                 101.0                    1/0/00  Corporate Auto
# 8  14072.0                  71.0                    1/0/00  Corporate Auto
# 9  28812.0                  93.0                    1/0/00    Special Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323
# 5   Two-Door Car          159.383042
# 6  Four-Door Car          321.600000
# 7  Four-Door Car          363.029680
# 8  Four-Door Car          511.200000
# 9  Four-Door Car          425.527834
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4999              847141.75%  63513.0                  70.0
# 5000              543121.91%  58161.0                  68.0
# 5001              568964.41%  83640.0                  70.0
# 5002              368672.38%      0.0                  96.0
# 5003              399258.39%      0.0                 111.0
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4999                    1/0/00   Personal Auto  Four-Door Car
# 5000                    1/0/00  Corporate Auto  Four-Door Car
# 5001                    1/0/00  Corporate Auto   Two-Door Car
# 5002                    1/0/00   Personal Auto   Two-Door Car
# 5003                    1/0/00   Personal Auto            SUV
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4999          185.667213
# 5000          140.747286
# 5001          471.050488
# 5002           28.460568
# 5003          700.349052
#
# [5004 rows x 11 columns]
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4999              847141.75%  63513.0                  70.0
# 5000              543121.91%  58161.0                  68.0
# 5001              568964.41%  83640.0                  70.0
# 5002              368672.38%      0.0                  96.0
# 5003              399258.39%      0.0                 111.0
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4999                    1/0/00   Personal Auto  Four-Door Car
# 5000                    1/0/00  Corporate Auto  Four-Door Car
# 5001                    1/0/00  Corporate Auto   Two-Door Car
# 5002                    1/0/00   Personal Auto   Two-Door Car
# 5003                    1/0/00   Personal Auto            SUV
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4999          185.667213
# 5000          140.747286
# 5001          471.050488
# 5002           28.460568
# 5003          700.349052
#
# [5004 rows x 11 columns]

# %% [markdown]
# **Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data**

# %%
insurance_df_all.drop(columns="customer", inplace=True)

# %% [markdown]
# **Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints)**

# %%
check_column_type = insurance_df_all_new.dtypes
print(check_column_type)

    #Fix column CLV
        ##Convert type with astype conversion method --> works only if data is clean and has no symbols (e. g. $) and if you want to convert a number to string
#insurance_df_all_new["customer lifetime value"].astype('str')

        #insurance_df_all_new['customer lifetime value'] = pd.to_numeric(insurance_df_all_new['customer lifetime value'])

def convert_column_clv(i):
    if i != i:
        pass 
    i = str(i).replace("%", "")
    return float(i)/100

#remove_percent = [i.replace('%','') for i in insurance_df_all_new["customer lifetime value"]]
#print(remove_percent[0:10])

insurance_df_all_new["customer lifetime value"] = insurance_df_all_new["customer lifetime value"].apply(convert_column_clv)
print(insurance_df_all_new["customer lifetime value"].head(10))


#test = insurance_df_all_new['customer lifetime value'].apply(lambda x: x.replace('%', '')).astype('float') / 100

def convert_column_complaints(i):
    if i != i:
        return 0
    i = str(i)
    return int(i[2])

insurance_df_all_new["number of open complaints"] = insurance_df_all_new["number of open complaints"].apply(convert_column_complaints)
print(insurance_df_all_new["number of open complaints"].head(100))
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object
# 0           NaN
# 1     6979.5359
# 2    12887.4317
# 3     7645.8618
# 4     5363.0765
# 5     8256.2978
# 6     5380.8986
# 7     7216.1003
# 8    24127.5040
# 9     7388.1781
# Name: customer lifetime value, dtype: float64
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    1
# 96    0
# 97    0
# 98    3
# 99    0
# Name: number of open complaints, Length: 100, dtype: int64

# %% [markdown]
# **Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns**

# %%
def update_column_state(i):
    if i != i:
        return i
    if str(i).endswith("li") == True:
        i = str(i).replace("Cali", "California")
    i = str(i).replace("AZ", "Arizona").replace("WA", "Washington")
    return str(i)

insurance_df_all_new["state"] = insurance_df_all_new["state"].apply(update_column_state)
print(insurance_df_all_new["state"].head(20))

print(insurance_df_all_new["state"].value_counts())
# Out:
# 0     Washington
# 1        Arizona
# 2         Nevada
# 3     California
# 4     Washington
# 5         Oregon
# 6         Oregon
# 7        Arizona
# 8         Oregon
# 9         Oregon
# 10    California
# 11    California
# 12    California
# 13       Arizona
# 14    California
# 15        Oregon
# 16        Nevada
# 17    California
# 18        Oregon
# 19    California
# Name: state, dtype: object
# Oregon        623
# California    608
# Arizona       402
# Nevada        223
# Washington    211
# Name: state, dtype: int64

# %% [markdown]
# **Removing duplicates**

# %%
print(insurance_df_all_new.drop_duplicates())
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# 3                   7645.8618      0.0                 106.0
# 4                   5363.0765  36357.0                  68.0
# ...                       ...      ...                   ...
# 4999                8471.4175  63513.0                  70.0
# 5000                5431.2191  58161.0                  68.0
# 5001                5689.6441  83640.0                  70.0
# 5002                3686.7238      0.0                  96.0
# 5003                3992.5839      0.0                 111.0
#
#       number of open complaints     policy type  vehicle class  \
# 0                             0   Personal Auto  Four-Door Car
# 1                             0   Personal Auto  Four-Door Car
# 2                             0   Personal Auto   Two-Door Car
# 3                             0  Corporate Auto            SUV
# 4                             0   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 4999                          0   Personal Auto  Four-Door Car
# 5000                          0  Corporate Auto  Four-Door Car
# 5001                          0  Corporate Auto   Two-Door Car
# 5002                          0   Personal Auto   Two-Door Car
# 5003                          0   Personal Auto            SUV
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4999          185.667213
# 5000          140.747286
# 5001          471.050488
# 5002           28.460568
# 5003          700.349052
#
# [2065 rows x 11 columns]

# %% [markdown]
# **Replacing null values – Replace missing values with means of the column (for numerical columns)**

# %% [markdown]
# ## Activity 2

# %% [markdown]
# **Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central**

# %%
def state_group(i):
    # checking for NaN. If x is NaN, return x
    if not i == i:
        return i
    
    else:

        dct_ = {'Washington':'west_coast',
                'Arizona':'midwest',
                'Nevada': 'midwest',
                'California':'west_coast',
                'Oregon':'west_coast',
               }
        
        return dct_[i]

insurance_df_all_new ['region'] = insurance_df_all_new['state'].apply(state_group)
insurance_df_all_new[['region', 'state']]
# Out:
#           region       state
# 0     west_coast  Washington
# 1        midwest     Arizona
# 2        midwest      Nevada
# 3     west_coast  California
# 4     west_coast  Washington
# ...          ...         ...
# 4999     midwest     Arizona
# 5000     midwest     Arizona
# 5001     midwest      Nevada
# 5002  west_coast  California
# 5003  west_coast  California
#
# [5004 rows x 2 columns]

# %% [markdown]
# **Standardizing the data – Use string functions to standardize the text data (lower case)**

# %% [markdown]
# ## Activity 3

# %%
#import new marketing file 
insurance_df2 = pd.read_csv('/Users/Annie/Documents/GitHub/IronAnne/Labs/Pandas/file3.csv')
print(insurance_df2.head())
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# **Which columns are numerical? Which columns are categorical?**

# %%
#numerical
def data_type_column_numerical():
    insurance_df2.select_dtypes(include=['int','float'])
    return True

# %%
insurance_df2.select_dtypes(include=['int','float'])
# Out:
#        Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                            0.0                   9          292.800000
# 1                            0.0                   1          744.924331
# 2                            0.0                   2          480.000000
# 3                            0.0                   2          484.013411
# 4                            NaN                   7          707.925645
# ...                          ...                 ...                 ...
# 10905                        NaN                   7         1214.400000
# 10906                        0.0                   6          273.018929
# 10907                        0.0                   2          381.306996
# 10908                        4.0                   6          618.288849
# 10909                        0.0                   3         1021.719397
#
# [10910 rows x 9 columns]

# %%
#categorical
insurance_df2.select_dtypes(include=['category', 'object'])
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0             Employed      M      Suburban        Married  Corporate Auto
# 1           Unemployed      F      Suburban         Single   Personal Auto
# 2             Employed      M      Suburban         Single   Personal Auto
# 3             Employed      M      Suburban         Single  Corporate Auto
# 4        Medical Leave      F      Suburban        Married   Personal Auto
# ...                ...    ...           ...            ...             ...
# 10905       Unemployed      F      Suburban        Married   Personal Auto
# 10906         Employed      F         Urban        Married   Personal Auto
# 10907         Employed      F         Rural        Married  Corporate Auto
# 10908         Employed      F         Urban       Divorced   Personal Auto
# 10909       Unemployed      M      Suburban         Single   Personal Auto
#
#              Policy Renew Offer Type Sales Channel  Vehicle Class  \
# 0      Corporate L3           Offer3         Agent  Four-Door Car
# 1       Personal L3           Offer4   Call Center  Four-Door Car
# 2       Personal L3           Offer3   Call Center            SUV
# 3      Corporate L3           Offer2        Branch  Four-Door Car
# 4       Personal L2           Offer1        Branch  Four-Door Car
# ...             ...              ...           ...            ...
# 10905   Personal L1           Offer3           Web     Luxury Car
# 10906   Personal L3           Offer2        Branch  Four-Door Car
# 10907  Corporate L3           Offer1           Web     Luxury SUV
# 10908   Personal L1           Offer1        Branch            SUV
# 10909   Personal L1           Offer4           Web            SUV
#
#       Vehicle Size Vehicle Type
# 0          Medsize          NaN
# 1          Medsize          NaN
# 2          Medsize            A
# 3          Medsize            A
# 4          Medsize          NaN
# ...            ...          ...
# 10905      Medsize            A
# 10906      Medsize            A
# 10907      Medsize          NaN
# 10908      Medsize            A
# 10909      Medsize          NaN
#
# [10910 rows x 17 columns]

# %% [markdown]
# **Check and deal with NaN values. (Hint: Replacing null values – Replace missing values with means of the column (for numerical columns)).**

# %%
#Overview NaN values  
pd.DataFrame(100 * insurance_df2.isna().sum()/len(insurance_df2), columns=['percent nan'])
# Out:
#                                percent nan
# Unnamed: 0                        0.000000
# Customer                          0.000000
# State                             5.783685
# Customer Lifetime Value           0.000000
# Response                          5.783685
# Coverage                          0.000000
# Education                         0.000000
# Effective To Date                 0.000000
# EmploymentStatus                  0.000000
# Gender                            0.000000
# Income                            0.000000
# Location Code                     0.000000
# Marital Status                    0.000000
# Monthly Premium Auto              0.000000
# Months Since Last Claim           5.802016
# Months Since Policy Inception     0.000000
# Number of Open Complaints         5.802016
# Number of Policies                0.000000
# Policy Type                       0.000000
# Policy                            0.000000
# Renew Offer Type                  0.000000
# Sales Channel                     0.000000
# Total Claim Amount                0.000000
# Vehicle Class                     5.701192
# Vehicle Size                      5.701192
# Vehicle Type                     50.247479

# %%
#filter all columns with numerical values 
while data_type_column_numerical() == True: 
    insurance_df3 = insurance_df2.fillna(insurance_df2.mean())
    break
#null values of categorical columns stay null / empty

# %%
insurance_df3.head(50)
# Out:
#     Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# 5            5  HO81102         NaN              4745.181764      NaN
# 6            6  IW72280  California              5035.035257       No
# 7            7  IH64929  California              4956.247235       No
# 8            8  FM55990  California              5989.773931      Yes
# 9            9  QX31376      Oregon             17114.328150       No
# 10          10  HG93801     Arizona              5154.764074       No
# 11          11  GE63585         NaN              2420.711888      NaN
# 12          12  EO51920      Oregon             19955.257130       No
# 13          13  KR82385  California              5454.587929       No
# 14          14  TL59568     Arizona             12836.009510       No
# 15          15  CW49887  California              4626.801093      Yes
# 16          16  FH51383  California              5326.677654       No
# 17          17  TR26615      Oregon              2497.531509       No
# 18          18  ZC97968  California              2736.352663       No
# 19          19  NJ54277  California              3746.751625      Yes
# 20          20  OM80593  California              7247.313475       No
# 21          21  RL65736      Oregon              6274.447705       No
# 22          22  EQ62488      Oregon             15031.564500       No
# 23          23  NQ71171  California              5107.071054       No
# 24          24  YK32760      Oregon              2502.209885       No
# 25          25  AY59197      Nevada              9521.222806       No
# 26          26  XF15789     Arizona              8869.619888       No
# 27          27  MQ68407      Oregon              4376.363592      Yes
# 28          28  CI99444      Nevada              2926.886293       No
# 29          29  BD70337  California             24706.920110       No
# 30          30  GX19342  California              8491.465719       No
# 31          31  DP19210  California              9191.733549       No
# 32          32  OJ63606     Arizona              5776.338737       No
# 33          33  OH23893  California              9115.571690       No
# 34          34  RI76930  California              4163.040810       No
# 35          35  YK26558  California              5264.642009       No
# 36          36  OE15005  California              3945.241604       No
# 37          37  RA17555      Oregon              5176.730072       No
# 38          38  ZI34278     Arizona              4492.233480       No
# 39          39  XD72019      Oregon              8470.043225       No
# 40          40  RR93140  California              2880.348532       No
# 41          41  BE25221     Arizona              6182.618843       No
# 42          42  PV62583      Nevada              9799.175061       No
# 43          43  BL12371     Arizona              5790.565333       No
# 44          44  ER49844     Arizona              5041.447024       No
# 45          45  RI22468     Arizona              5745.943340       No
# 46          46  SY48591     Arizona              4827.776810       No
# 47          47  PR23514  California              7664.219255       No
# 48          48  UY32623  California              3593.126450       No
# 49          49  QV30663      Nevada              9863.502214       No
#
#     Coverage             Education Effective To Date EmploymentStatus Gender  \
# 0      Basic               College           2/18/11         Employed      M
# 1      Basic               College           1/18/11       Unemployed      F
# 2      Basic              Bachelor           2/10/11         Employed      M
# 3   Extended               College           1/11/11         Employed      M
# 4    Premium              Bachelor           1/17/11    Medical Leave      F
# 5      Basic  High School or Below           2/14/11         Employed      M
# 6      Basic                Doctor           2/14/11         Employed      F
# 7      Basic  High School or Below           2/24/11         Employed      M
# 8    Premium               College           1/19/11         Employed      M
# 9   Extended                Master            1/4/11         Employed      F
# 10  Extended  High School or Below            1/2/11         Employed      M
# 11     Basic              Bachelor            2/7/11         Employed      M
# 12  Extended  High School or Below           1/31/11         Employed      F
# 13     Basic                Master           1/26/11         Employed      M
# 14   Premium  High School or Below           2/28/11       Unemployed      M
# 15     Basic                Master           1/16/11         Employed      F
# 16     Basic  High School or Below            2/7/11         Employed      F
# 17     Basic  High School or Below           1/17/11       Unemployed      M
# 18     Basic               College           2/14/11         Disabled      M
# 19  Extended               College           2/26/11         Employed      F
# 20     Basic              Bachelor           2/23/11       Unemployed      F
# 21  Extended  High School or Below           2/14/11    Medical Leave      F
# 22     Basic               College           1/15/11         Employed      F
# 23     Basic              Bachelor            2/2/11         Employed      M
# 24     Basic  High School or Below           2/15/11       Unemployed      M
# 25  Extended               College           1/24/11         Employed      M
# 26     Basic               College           2/21/11         Employed      F
# 27   Premium              Bachelor           2/28/11         Employed      F
# 28     Basic               College           2/22/11         Employed      F
# 29     Basic  High School or Below            1/7/11    Medical Leave      M
# 30   Premium  High School or Below           1/28/11       Unemployed      F
# 31     Basic                Master            2/8/11         Employed      F
# 32   Premium  High School or Below           1/28/11    Medical Leave      F
# 33     Basic              Bachelor           2/15/11         Employed      F
# 34     Basic               College           2/12/11         Employed      F
# 35     Basic               College           2/20/11       Unemployed      F
# 36     Basic               College            1/5/11    Medical Leave      M
# 37     Basic  High School or Below            2/7/11         Employed      M
# 38     Basic              Bachelor           1/28/11    Medical Leave      F
# 39  Extended              Bachelor           2/19/11       Unemployed      F
# 40     Basic               College            1/5/11         Employed      F
# 41  Extended  High School or Below            2/7/11    Medical Leave      M
# 42  Extended               College            1/3/11    Medical Leave      M
# 43     Basic                Master            2/3/11         Employed      M
# 44     Basic               College           1/19/11         Employed      M
# 45     Basic              Bachelor           1/22/11         Employed      F
# 46     Basic               College           1/17/11       Unemployed      F
# 47     Basic               College           1/23/11         Employed      M
# 48  Extended               College            2/5/11         Disabled      F
# 49  Extended                Master           2/28/11         Employed      F
#
#     ...  Number of Open Complaints Number of Policies     Policy Type  \
# 0   ...                   0.000000                  9  Corporate Auto
# 1   ...                   0.000000                  1   Personal Auto
# 2   ...                   0.000000                  2   Personal Auto
# 3   ...                   0.000000                  2  Corporate Auto
# 4   ...                   0.384256                  7   Personal Auto
# 5   ...                   0.000000                  7   Personal Auto
# 6   ...                   3.000000                  4  Corporate Auto
# 7   ...                   0.000000                  3   Personal Auto
# 8   ...                   0.000000                  1   Personal Auto
# 9   ...                   0.000000                  2  Corporate Auto
# 10  ...                   0.000000                  1  Corporate Auto
# 11  ...                   0.000000                  1  Corporate Auto
# 12  ...                   0.000000                  2  Corporate Auto
# 13  ...                   0.000000                  4   Personal Auto
# 14  ...                   0.000000                  2   Personal Auto
# 15  ...                   0.000000                  1    Special Auto
# 16  ...                   0.000000                  6   Personal Auto
# 17  ...                   0.000000                  1  Corporate Auto
# 18  ...                   0.000000                  1   Personal Auto
# 19  ...                   1.000000                  1   Personal Auto
# 20  ...                   0.000000                  7   Personal Auto
# 21  ...                   0.000000                  3   Personal Auto
# 22  ...                   0.000000                  8   Personal Auto
# 23  ...                   0.384256                  7   Personal Auto
# 24  ...                   1.000000                  1  Corporate Auto
# 25  ...                   0.000000                  6    Special Auto
# 26  ...                   0.000000                  9   Personal Auto
# 27  ...                   0.000000                  1   Personal Auto
# 28  ...                   0.000000                  1    Special Auto
# 29  ...                   0.000000                  2   Personal Auto
# 30  ...                   0.000000                  3   Personal Auto
# 31  ...                   0.000000                  6  Corporate Auto
# 32  ...                   3.000000                  1  Corporate Auto
# 33  ...                   0.000000                  6   Personal Auto
# 34  ...                   0.000000                  1   Personal Auto
# 35  ...                   0.000000                  8    Special Auto
# 36  ...                   0.000000                  1   Personal Auto
# 37  ...                   0.000000                  9  Corporate Auto
# 38  ...                   1.000000                  6   Personal Auto
# 39  ...                   0.000000                  2   Personal Auto
# 40  ...                   0.000000                  1   Personal Auto
# 41  ...                   0.000000                  9  Corporate Auto
# 42  ...                   0.000000                  6   Personal Auto
# 43  ...                   0.000000                  5   Personal Auto
# 44  ...                   2.000000                  5   Personal Auto
# 45  ...                   3.000000                  9   Personal Auto
# 46  ...                   0.000000                  6   Personal Auto
# 47  ...                   1.000000                  1   Personal Auto
# 48  ...                   1.000000                  1  Corporate Auto
# 49  ...                   0.000000                  3   Personal Auto
#
#           Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0   Corporate L3            Offer3          Agent          292.800000
# 1    Personal L3            Offer4    Call Center          744.924331
# 2    Personal L3            Offer3    Call Center          480.000000
# 3   Corporate L3            Offer2         Branch          484.013411
# 4    Personal L2            Offer1         Branch          707.925645
# 5    Personal L3            Offer1          Agent          292.800000
# 6   Corporate L2            Offer2         Branch          287.556107
# 7    Personal L2            Offer2         Branch          247.402353
# 8    Personal L1            Offer2         Branch          739.200000
# 9   Corporate L3            Offer2          Agent          408.000000
# 10  Corporate L3            Offer2         Branch          442.521087
# 11  Corporate L3            Offer1    Call Center          199.551735
# 12  Corporate L3            Offer1          Agent           64.669515
# 13   Personal L3            Offer4    Call Center          331.200000
# 14   Personal L2            Offer3          Agent          835.200000
# 15    Special L1            Offer2         Branch          547.200000
# 16   Personal L3            Offer4    Call Center          300.528579
# 17  Corporate L2            Offer2         Branch          272.381465
# 18   Personal L3            Offer1          Agent          350.400000
# 19   Personal L2            Offer2    Call Center           19.575683
# 20   Personal L3            Offer1    Call Center          499.200000
# 21   Personal L1            Offer1          Agent          408.000000
# 22   Personal L3            Offer2    Call Center          907.200000
# 23   Personal L2            Offer1          Agent          128.900320
# 24  Corporate L1            Offer1          Agent          355.200000
# 25    Special L3            Offer4          Agent          123.154160
# 26   Personal L3            Offer3         Branch          228.185834
# 27   Personal L3            Offer2          Agent           60.036683
# 28    Special L2            Offer2    Call Center          234.774747
# 29   Personal L2            Offer4    Call Center          313.192439
# 30   Personal L3            Offer1         Branch         1193.115879
# 31  Corporate L2            Offer2         Branch          567.480550
# 32  Corporate L3            Offer1    Call Center          871.457982
# 33   Personal L1            Offer1         Branch          173.080024
# 34   Personal L3            Offer2    Call Center          499.200000
# 35    Special L3            Offer1         Branch          135.888306
# 36   Personal L2            Offer3    Call Center          647.442031
# 37  Corporate L2            Offer3          Agent          232.879766
# 38   Personal L1            Offer2            Web          292.800000
# 39   Personal L2            Offer2            Web          479.312226
# 40   Personal L2            Offer2         Branch          190.642833
# 41  Corporate L3            Offer1          Agent          473.266879
# 42   Personal L3            Offer1            Web          604.800000
# 43   Personal L3            Offer2          Agent           28.925840
# 44   Personal L1            Offer4    Call Center          138.961963
# 45   Personal L1            Offer3            Web          269.905129
# 46   Personal L3            Offer1         Branch          326.400000
# 47   Personal L3            Offer2            Web          161.615740
# 48  Corporate L2            Offer1         Branch          460.800000
# 49   Personal L3            Offer3    Call Center          272.788141
#
#     Vehicle Class Vehicle Size Vehicle Type
# 0   Four-Door Car      Medsize          NaN
# 1   Four-Door Car      Medsize          NaN
# 2             SUV      Medsize            A
# 3   Four-Door Car      Medsize            A
# 4   Four-Door Car      Medsize          NaN
# 5   Four-Door Car      Medsize            A
# 6   Four-Door Car      Medsize          NaN
# 7    Two-Door Car      Medsize          NaN
# 8      Sports Car      Medsize          NaN
# 9   Four-Door Car        Small          NaN
# 10            SUV        Large            A
# 11   Two-Door Car      Medsize          NaN
# 12  Four-Door Car      Medsize          NaN
# 13   Two-Door Car      Medsize            A
# 14   Two-Door Car      Medsize          NaN
# 15            SUV      Medsize          NaN
# 16   Two-Door Car        Large            A
# 17   Two-Door Car      Medsize            A
# 18   Two-Door Car      Medsize            A
# 19   Two-Door Car        Large            A
# 20            SUV      Medsize            A
# 21  Four-Door Car        Small          NaN
# 22     Luxury Car        Large            A
# 23  Four-Door Car      Medsize          NaN
# 24  Four-Door Car      Medsize            A
# 25            SUV        Small            A
# 26            SUV        Large            A
# 27  Four-Door Car      Medsize          NaN
# 28  Four-Door Car      Medsize            A
# 29  Four-Door Car      Medsize          NaN
# 30  Four-Door Car        Large            A
# 31     Sports Car      Medsize          NaN
# 32            SUV        Small            A
# 33            SUV      Medsize          NaN
# 34            SUV        Large          NaN
# 35  Four-Door Car      Medsize          NaN
# 36            SUV      Medsize          NaN
# 37  Four-Door Car      Medsize          NaN
# 38  Four-Door Car      Medsize          NaN
# 39  Four-Door Car        Large            A
# 40  Four-Door Car      Medsize            A
# 41  Four-Door Car      Medsize          NaN
# 42            SUV      Medsize            A
# 43  Four-Door Car        Large            A
# 44  Four-Door Car      Medsize          NaN
# 45  Four-Door Car      Medsize            A
# 46  Four-Door Car      Medsize          NaN
# 47     Luxury SUV      Medsize          NaN
# 48  Four-Door Car        Large            A
# 49            SUV      Medsize            A
#
# [50 rows x 26 columns]

# %%
#check again NaN values
pd.DataFrame(100 * insurance_df3.isna().sum()/len(insurance_df3), columns=['percent nan'])
# Out:
#                                percent nan
# Unnamed: 0                        0.000000
# Customer                          0.000000
# State                             5.783685
# Customer Lifetime Value           0.000000
# Response                          5.783685
# Coverage                          0.000000
# Education                         0.000000
# Effective To Date                 0.000000
# EmploymentStatus                  0.000000
# Gender                            0.000000
# Income                            0.000000
# Location Code                     0.000000
# Marital Status                    0.000000
# Monthly Premium Auto              0.000000
# Months Since Last Claim           0.000000
# Months Since Policy Inception     0.000000
# Number of Open Complaints         0.000000
# Number of Policies                0.000000
# Policy Type                       0.000000
# Policy                            0.000000
# Renew Offer Type                  0.000000
# Sales Channel                     0.000000
# Total Claim Amount                0.000000
# Vehicle Class                     5.701192
# Vehicle Size                      5.701192
# Vehicle Type                     50.247479

# %% [markdown]
# **Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.**

# %%
from datetime import datetime
import pandas as pd
import numpy as np

#change dtype from "object" to datetime & check 
insurance_df3['Effective To Date'] = pd.to_datetime(insurance_df3['Effective To Date'])
print(insurance_df3['Effective To Date'].dtype)

'''How does python know the weird date format (M/DD/YY) and extract the right value?'''
#extract year, month and day to new columns:
    #df['year'] = df['date'].dt.year
    #df['day'] = df['date'].dt.day
    
insurance_df3['month'] = insurance_df3['Effective To Date'].dt.month
print(insurance_df3['month'])

#Filter the data and show only first quarter 
insurance_df3[(insurance_df3['month'] == 1) | (insurance_df3['month'] == 2) | (insurance_df3['month'] == 3)]


"""why does numpy not work?"""
"""insurance_df3[np.where(insurance_df3['Effective To Date'].isin([1,2])) == True]"""
# Out:
# datetime64[ns]
# 0        2
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 10905    1
# 10906    1
# 10907    2
# 10908    2
# 10909    1
# Name: month, Length: 10910, dtype: int64
# "insurance_df3[np.where(insurance_df3['Effective To Date'].isin([1,2])) == True]"

# %%
#Change format from numerical to categorical
insurance_df3["month"] = list(map(lambda date: date.strftime(format="%B"), insurance_df3["Effective To Date"]))
insurance_df3["month"]
# Out:
# 0        February
# 1         January
# 2        February
# 3         January
# 4         January
#            ...
# 10905     January
# 10906     January
# 10907    February
# 10908    February
# 10909     January
# Name: month, Length: 10910, dtype: object

# %% [markdown]
# **BONUS: Put all the previously mentioned data transformations into a function/functions.**

# %%
#def replace_NaN()
    ##select numerical columns (dtype)
    ##substitute with mean() for each column
    ##leave categorical as they are 
    
#def extract_months()
    #change object to datetime dtype 
    #extract months and insert in new column 
    #filter Jan, Feb, (Mar)
    #format number (2) to word (January)

# %% [markdown]
# # Activity 4

# %% [markdown]
# First, as an aid, you can find cheatsheets for Matplotlib and Seaborn below:
# - [Matplotlib Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
# - [Seaborn Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Seaborn_Cheat_Sheet.pdf)
# - [Colors Cheat Sheet]
# (https://matplotlib.org/stable/tutorials/colors/colors.html)

# %%
# import libraries to use (pandas, numpy, matplotlib.pyplot and seaborn)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **1. Show a plot of the total number of responses.**

# %%
#Bar chart with 2 bars (yes=1467/no=8814 (631 = blank)); value_counts 
#Visualisation as a stacked bar chart

num_response = insurance_df3["Response"].value_counts()
num_response
# Out:
# No     8813
# Yes    1466
# Name: Response, dtype: int64

# %%
# create figure and axes with subplots()
fig1, ax1 = plt.subplots(1)

# set_title()
ax1.set_title("Total Number of Responses")

# plot the bar chart with bar() & create bars with different colors 
sns.barplot(x=num_response.index, y =num_response, color=("#00FFFF"),  edgecolor='magenta')
# Out:
# <AxesSubplot:title={'center':'Total Number of Responses'}, ylabel='Response'>

# %%
#official solution
sns.countplot('response', data=customers_df)
plt.ylabel('Total number of Response')
plt.show()
# Out:
# /Users/testaccount/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **2. Show a plot of the response rate by the sales channel.**

# %%
insurance_df3_without_nan = insurance_df3.dropna(subset = ["Response"], inplace=True)

# %%
#Get an overview and show responses per sales channel 
s_grouped = insurance_df3.groupby(['Sales Channel', 'Response'])['Customer'].count().reset_index()
s_grouped
# Out:
#   Sales Channel Response  Customer
# 0         Agent       No      3148
# 1         Agent      Yes       742
# 2        Branch       No      2539
# 3        Branch      Yes       326
# 4   Call Center       No      1792
# 5   Call Center      Yes       221
# 6           Web       No      1334
# 7           Web      Yes       177

# %%
group_by_yes = s_grouped[s_grouped["Response"] == "Yes"]
group_by_yes

col_cust_list = group_by_yes['Customer'].tolist()
col_cust_list
# Out:
# [742, 326, 221, 177]

# %%
sales_channel_list = group_by_yes['Sales Channel'].tolist()
sales_channel_list
# Out:
# ['Agent', 'Branch', 'Call Center', 'Web']

# %%
group_by_total = insurance_df3.groupby(['Sales Channel'])['Response'].count().reset_index()
group_by_total

group_by_total_list = group_by_total["Response"].tolist()
group_by_total_list
# Out:
# [3890, 2865, 2013, 1511]

# %%
response_rates = [i / j for i, j in zip(col_cust_list, group_by_total_list)]
response_rates
# Out:
# [0.19074550128534704,
#  0.1137870855148342,
#  0.10978638847491307,
#  0.1171409662475182]

# %%
response_rates = [0.19074550128534704,
 0.1137870855148342,
 0.10978638847491307,
 0.1171409662475182]

channel = ['Agent', 'Branch', 'Call Center', 'Web']

# Create names on the x-axis
plt.xticks(response_rates, channel)

# Create bars with different colors
plt.bar(channel, response_rates, color=['red', 'green', 'blue', 'cyan'])

# Show graph
plt.show()

# %% [markdown]
# **Show a plot of the response rate by the total claim amount.**

# %%
insurance_df3["Total Claim Amount"].describe()
# Out:
# count    10279.000000
# mean       435.736506
# std        292.321294
# min          0.099007
# 25%        272.788141
# 50%        384.000000
# 75%        548.327777
# max       2893.239678
# Name: Total Claim Amount, dtype: float64

# %%
insurance_df3["Total Claim Amount"].hist()
# Out:
# <AxesSubplot:>

# %%
#official solution

plt.figure(figsize=(8,4))
sns.countplot('response', hue='sales_channel', data=customers_df)
plt.ylabel('Response by Sales Channel')
plt.show()
# Out:
# /Users/testaccount/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Show a plot of the response rate by income.**

# %%
#check percentiles and distribution to form income classes
insurance_df3["Income"].describe()

#write a function that attributes each value to a class
def groups():
    for i in insurance_df3["Income"]:
        if i < 33837 = "Low"
        elif 33837 > i < 62100.5 = "Middle"
        elif 62100.5 > i < 99981 = "High"

#create a new column = attribues each income to one of the 3 groups 
#get response rates: count yes responses in each class and divide by overall responses in each class

#deliverables 
responses_rates_per_income_class = [x, y, z]
income_classes = ["Low", "Middle", "High"]
# Out:
#   File "<ipython-input-279-f79499becbd6>", line 4
#     if i < 33837 = low_income
#                  ^
# SyntaxError: invalid syntax

# %%
#official solution 
plt.figure(figsize=(12,6))
sns.boxplot(y='total_claim_amount' , x='response', data=customers_df)
plt.ylabel('Response by Total Claim Amount')
plt.show()

# %% [markdown]
# **Show a plot of the response rate by the total claim amount.**

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y='total_claim_amount' , x='response', data=customers_df)
plt.ylabel('Response by Total Claim Amount')
plt.show()

# %% [markdown]
# *Don't Limit your creativity! plot Any interesting findings/insights that describe some interesting facts about your data set and its variables. Use the relevant plotting when you feel it is needed.*

# %% [markdown]
# Let's do an interactive map

# %% [markdown]
# **Plot the Correlation Heatmap.**

# %%
# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(insurance_df3.corr())
  
# plotting correlation heatmap
dataplot = sns.heatmap(insurance_df3.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()
# Out:
#                                Unnamed: 0  Customer Lifetime Value    Income  \
# Unnamed: 0                       1.000000                -0.001973  0.007324
# Customer Lifetime Value         -0.001973                 1.000000  0.027544
# Income                           0.007324                 0.027544  1.000000
# Monthly Premium Auto            -0.000721                 0.403531 -0.011783
# Months Since Last Claim          0.006274                 0.016087 -0.021217
# Months Since Policy Inception    0.013372                 0.010915 -0.001657
# Number of Open Complaints        0.005139                -0.029076  0.004134
# Number of Policies               0.003552                 0.016925 -0.011334
# Total Claim Amount              -0.000316                 0.231934 -0.354541
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Unnamed: 0                                -0.000721                 0.006274
# Customer Lifetime Value                    0.403531                 0.016087
# Income                                    -0.011783                -0.021217
# Monthly Premium Auto                       1.000000                 0.007418
# Months Since Last Claim                    0.007418                 1.000000
# Months Since Policy Inception              0.018108                -0.038887
# Number of Open Complaints                 -0.009283                 0.006203
# Number of Policies                        -0.018379                 0.006601
# Total Claim Amount                         0.631410                 0.010096
#
#                                Months Since Policy Inception  \
# Unnamed: 0                                          0.013372
# Customer Lifetime Value                             0.010915
# Income                                             -0.001657
# Monthly Premium Auto                                0.018108
# Months Since Last Claim                            -0.038887
# Months Since Policy Inception                       1.000000
# Number of Open Complaints                           0.001754
# Number of Policies                                 -0.012195
# Total Claim Amount                                  0.002423
#
#                                Number of Open Complaints  Number of Policies  \
# Unnamed: 0                                      0.005139            0.003552
# Customer Lifetime Value                        -0.029076            0.016925
# Income                                          0.004134           -0.011334
# Monthly Premium Auto                           -0.009283           -0.018379
# Months Since Last Claim                         0.006203            0.006601
# Months Since Policy Inception                   0.001754           -0.012195
# Number of Open Complaints                       1.000000            0.001502
# Number of Policies                              0.001502            1.000000
# Total Claim Amount                             -0.008907           -0.009154
#
#                                Total Claim Amount
# Unnamed: 0                              -0.000316
# Customer Lifetime Value                  0.231934
# Income                                  -0.354541
# Monthly Premium Auto                     0.631410
# Months Since Last Claim                  0.010096
# Months Since Policy Inception            0.002423
# Number of Open Complaints               -0.008907
# Number of Policies                      -0.009154
# Total Claim Amount                       1.000000

# %%
#Bita
#----correlation heatmap: calculation to make diagonals zero-----#

core_df = numericals.corr()
corr_matrix = np.array(core_df)
unit_matrix = np.eye(8)    #corr_matrix.shape --> 8
correlation = corr_matrix - unit_matrix

#print(correlation)

# %%
#---- visualization----#

#corr_map = sns.heatmap(correlation)      #--- the diagonal values are zero ---#

sns.heatmap(round(df.corr(),2), annot = True, cmap="seismic", center = 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# *Clean your notebook and make it a readible and presentable with a good documentation that summarizes the Data Cleaning, Exploration(including plots) Steps that you have performed.*

# %%
#solutions from Rafa
#Activity 3
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %%
def load_original_data():
    return pd.read_csv("/Users/Annie/Documents/GitHub/IronAnne/Labs/16_Statistics/file3.csv" )

# %%
def clean_data(df):
    df.columns=[e.lower().replace(' ', '_') for e in df.columns]
    df=df.drop(columns=['vehicle_type'])
    df=df.dropna()
    df['effective_to_date']=pd.to_datetime(df['effective_to_date'], errors='coerce')
    df["month"]=list(map(lambda date:date.strftime(format="%B"),df["effective_to_date"]))
    return df

# %%
customers_df=load_original_data()

# %%
customers_df=customers_df.iloc[:,1:]

# %%
customers_df[customers_df.Customer=="BV86143"]
# Out:
#      Customer       State  Customer Lifetime Value Response Coverage  \
# 729   BV86143         NaN              21034.01815      NaN    Basic
# 1134  BV86143         NaN              21034.01815      NaN    Basic
# 2178  BV86143  California              21034.01815       No    Basic
#
#                  Education Effective To Date EmploymentStatus Gender  Income  \
# 729   High School or Below           2/23/11         Employed      F   26876
# 1134  High School or Below           2/23/11         Employed      F   26876
# 2178  High School or Below           2/23/11         Employed      F   26876
#
#       ... Number of Open Complaints Number of Policies    Policy Type  \
# 729   ...                       0.0                  2  Personal Auto
# 1134  ...                       0.0                  2  Personal Auto
# 2178  ...                       0.0                  2  Personal Auto
#
#            Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 729   Personal L2            Offer4    Call Center          219.209762
# 1134  Personal L2            Offer4    Call Center          219.209762
# 2178  Personal L2            Offer4    Call Center          219.209762
#
#       Vehicle Class Vehicle Size Vehicle Type
# 729   Four-Door Car      Medsize            A
# 1134  Four-Door Car      Medsize            A
# 2178  Four-Door Car      Medsize          NaN
#
# [3 rows x 25 columns]

# %%
len(customers_df[customers_df.duplicated()])
# Out:
# 37

# %%
customers_df=clean_data(customers_df)
customers_df.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %% [markdown]
# ## Activity 5

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import scipy as sc 
import ipywidgets as widgets
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#import new marketing file 
#df1 = pd.read_csv('/Users/Annie/Documents/GitHub/IronAnne/Labs/16_Statistics/file3.csv')
df1 = customers_df
#print(df1.head())

#import health insurance file 
df2 = pd.read_csv('/Users/Annie/Documents/GitHub/IronAnne/Labs/16_Statistics/healthcare.csv')
#df2.head()

# %% [markdown]
# **Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)**

# %%
numericals = df1.select_dtypes(include=[np.number])
numericals

#categoricals = df1.select_dtypes(include=[np.object])
#categoricals
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 6                  5035.035257   37405                    63
# ...                        ...     ...                   ...
# 10903              2771.663013   59855                    74
# 10904             19228.463620       0                   187
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 6                          8.0                             99
# ...                        ...                            ...
# 10903                     30.0                             82
# 10904                     14.0                             32
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                            0.0                   9          292.800000
# 1                            0.0                   1          744.924331
# 2                            0.0                   2          480.000000
# 3                            0.0                   2          484.013411
# 6                            3.0                   4          287.556107
# ...                          ...                 ...                 ...
# 10903                        4.0                   1          355.200000
# 10904                        0.0                   2          897.600000
# 10906                        0.0                   6          273.018929
# 10907                        0.0                   2          381.306996
# 10908                        4.0                   6          618.288849
#
# [9134 rows x 8 columns]

# %% [markdown]
# **Now we will try to check the normality of the numerical variables visually**
#
# - Use seaborn library to construct distribution plots for the numerical variables
# - Use Matplotlib to construct histograms
# - Do the distributions for different numerical variables look like a normal distribution?

# %%
numericals.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              4809.216960   48029                    61
# 1              2228.525238       0                    64
# 2             14947.917300   22139                   100
# 3             22332.439460   49078                    97
# 6              5035.035257   37405                    63
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                      7.0                             52
# 1                      3.0                             26
# 2                     34.0                             31
# 3                     10.0                              3
# 6                      8.0                             99
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                        0.0                   9          292.800000
# 1                        0.0                   1          744.924331
# 2                        0.0                   2          480.000000
# 3                        0.0                   2          484.013411
# 6                        3.0                   4          287.556107

# %%
#sns.displot(df1["Customer Lifetime Value"])
sns.distplot(df1["customer_lifetime_value"], hist = True)
plt.show()
# Out:
# /Users/testaccount/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#sns.displot(df1["Income"])
sns.distplot(df1["income"], hist = True)

plt.show()
# Out:
# /Users/testaccount/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#sns.displot(df1["Number of Open Complaints"])
sns.distplot(df1["number_of_open_complaints"], hist = True)

plt.show()
# Out:
# /Users/testaccount/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#sns.displot(df1["Total Claim Amount"])
sns.distplot(df1["total_claim_amount"], hist = True)

plt.show()
# Out:
# /Users/testaccount/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Normalize (numericals)**

# %%
# visualize a box-cox transform of the sonar dataset
from pandas import read_csv
from pandas import DataFrame
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# Load dataset
#url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"
#dataset = read_csv(url, header=None)

# retrieve just the numeric input values
data = numericals.values[:, :-1]

# perform a box-cox transform of the dataset
scaler = MinMaxScaler(feature_range=(1, 2))
power = PowerTransformer(method='box-cox')
pipeline = Pipeline(steps=[('s', scaler),('p', power)])
data = pipeline.fit_transform(data)

# convert the array back to a dataframe
dataset = DataFrame(data)

# histograms of the variables
dataset.hist()
pyplot.show()

# %% [markdown]
# **For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.**

# %% [markdown]
# *Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features.*

# %%
# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(numericals.corr())
  
# plotting correlation heatmap
dataplot = sns.heatmap(numericals.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# months_since_last_claim                    0.005026                 1.000000
# months_since_policy_inception              0.020257                -0.042959
# number_of_open_complaints                 -0.013122                 0.005354
# number_of_policies                        -0.011233                 0.009136
# total_claim_amount                         0.632017                 0.007563
#
#                                months_since_policy_inception  \
# customer_lifetime_value                             0.009418
# income                                             -0.000875
# monthly_premium_auto                                0.020257
# months_since_last_claim                            -0.042959
# months_since_policy_inception                       1.000000
# number_of_open_complaints                          -0.001158
# number_of_policies                                 -0.013333
# total_claim_amount                                  0.003335
#
#                                number_of_open_complaints  number_of_policies  \
# customer_lifetime_value                        -0.036343            0.021955
# income                                          0.006408           -0.008656
# monthly_premium_auto                           -0.013122           -0.011233
# months_since_last_claim                         0.005354            0.009136
# months_since_policy_inception                  -0.001158           -0.013333
# number_of_open_complaints                       1.000000            0.001498
# number_of_policies                              0.001498            1.000000
# total_claim_amount                             -0.014241           -0.002354
#
#                                total_claim_amount
# customer_lifetime_value                  0.226451
# income                                  -0.355254
# monthly_premium_auto                     0.632017
# months_since_last_claim                  0.007563
# months_since_policy_inception            0.003335
# number_of_open_complaints               -0.014241
# number_of_policies                      -0.002354
# total_claim_amount                       1.000000

# %%
#health insurance data 
numericals_2 = df2.select_dtypes(include=[np.number])
numericals_2

# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(numericals_2.corr())
# Out:
#                                          CONTROL NUMBER  \
# CONTROL NUMBER                                 1.000000
# HOME VALUE in % (HVP1) >= $200,000             0.257509
# MEDIAN HOUSEHOLD INCOME (IC1)                  0.141646
# MEDIAN FAMILY INCOME in hundreds (IC2)         0.134876
# AV. HOUSEHOLD INCOME in hundreds (IC3)         0.140370
# AV. FAMILY INCOME in hundreds (IC4)            0.128768
# PER CAPITA INCOME (IC5)                        0.106666
# FOREIGN BORN (in %) (POBC1)                    0.182664
# BORN IN STATE OF RESIDENCE in % (POBC2)       -0.124787
# AVGGIFT                                        0.044976
# DONOR TITLE CODE (TCODE)                       0.007538
# AGE                                            0.032453
# DOMAIN_SOCIO-ECONOMIC-STATUS                  -0.089187
# Unnamed: 20                                         NaN
# Reference Date                                      NaN
# 01.06.1997                                          NaN
#
#                                          HOME VALUE in % (HVP1) >= $200,000  \
# CONTROL NUMBER                                                     0.257509
# HOME VALUE in % (HVP1) >= $200,000                                 1.000000
# MEDIAN HOUSEHOLD INCOME (IC1)                                      0.591739
# MEDIAN FAMILY INCOME in hundreds (IC2)                             0.618697
# AV. HOUSEHOLD INCOME in hundreds (IC3)                             0.626621
# AV. FAMILY INCOME in hundreds (IC4)                                0.636549
# PER CAPITA INCOME (IC5)                                            0.585630
# FOREIGN BORN (in %) (POBC1)                                        0.418266
# BORN IN STATE OF RESIDENCE in % (POBC2)                           -0.217391
# AVGGIFT                                                            0.105605
# DONOR TITLE CODE (TCODE)                                          -0.014382
# AGE                                                                0.028343
# DOMAIN_SOCIO-ECONOMIC-STATUS                                      -0.107111
# Unnamed: 20                                                             NaN
# Reference Date                                                          NaN
# 01.06.1997                                                              NaN
#
#                                          MEDIAN HOUSEHOLD INCOME (IC1)  \
# CONTROL NUMBER                                                0.141646
# HOME VALUE in % (HVP1) >= $200,000                            0.591739
# MEDIAN HOUSEHOLD INCOME (IC1)                                 1.000000
# MEDIAN FAMILY INCOME in hundreds (IC2)                        0.952182
# AV. HOUSEHOLD INCOME in hundreds (IC3)                        0.974293
# AV. FAMILY INCOME in hundreds (IC4)                           0.929160
# PER CAPITA INCOME (IC5)                                       0.800237
# FOREIGN BORN (in %) (POBC1)                                   0.158926
# BORN IN STATE OF RESIDENCE in % (POBC2)                      -0.196077
# AVGGIFT                                                       0.123165
# DONOR TITLE CODE (TCODE)                                      0.003085
# AGE                                                          -0.002213
# DOMAIN_SOCIO-ECONOMIC-STATUS                                 -0.078905
# Unnamed: 20                                                        NaN
# Reference Date                                                     NaN
# 01.06.1997                                                         NaN
#
#                                          MEDIAN FAMILY INCOME in hundreds (IC2)  \
# CONTROL NUMBER                                                         0.134876
# HOME VALUE in % (HVP1) >= $200,000                                     0.618697
# MEDIAN HOUSEHOLD INCOME (IC1)                                          0.952182
# MEDIAN FAMILY INCOME in hundreds (IC2)                                 1.000000
# AV. HOUSEHOLD INCOME in hundreds (IC3)                                 0.953196
# AV. FAMILY INCOME in hundreds (IC4)                                    0.969978
# PER CAPITA INCOME (IC5)                                                0.872437
# FOREIGN BORN (in %) (POBC1)                                            0.158699
# BORN IN STATE OF RESIDENCE in % (POBC2)                               -0.212700
# AVGGIFT                                                                0.139765
# DONOR TITLE CODE (TCODE)                                               0.009813
# AGE                                                                   -0.009438
# DOMAIN_SOCIO-ECONOMIC-STATUS                                          -0.066096
# Unnamed: 20                                                                 NaN
# Reference Date                                                              NaN
# 01.06.1997                                                                  NaN
#
#                                          AV. HOUSEHOLD INCOME in hundreds (IC3)  \
# CONTROL NUMBER                                                         0.140370
# HOME VALUE in % (HVP1) >= $200,000                                     0.626621
# MEDIAN HOUSEHOLD INCOME (IC1)                                          0.974293
# MEDIAN FAMILY INCOME in hundreds (IC2)                                 0.953196
# AV. HOUSEHOLD INCOME in hundreds (IC3)                                 1.000000
# AV. FAMILY INCOME in hundreds (IC4)                                    0.971984
# PER CAPITA INCOME (IC5)                                                0.824082
# FOREIGN BORN (in %) (POBC1)                                            0.179144
# BORN IN STATE OF RESIDENCE in % (POBC2)                               -0.227009
# AVGGIFT                                                                0.129303
# DONOR TITLE CODE (TCODE)                                              -0.000968
# AGE                                                                   -0.000989
# DOMAIN_SOCIO-ECONOMIC-STATUS                                          -0.078070
# Unnamed: 20                                                                 NaN
# Reference Date                                                              NaN
# 01.06.1997                                                                  NaN
#
#                                          AV. FAMILY INCOME in hundreds (IC4)  \
# CONTROL NUMBER                                                      0.128768
# HOME VALUE in % (HVP1) >= $200,000                                  0.636549
# MEDIAN HOUSEHOLD INCOME (IC1)                                       0.929160
# MEDIAN FAMILY INCOME in hundreds (IC2)                              0.969978
# AV. HOUSEHOLD INCOME in hundreds (IC3)                              0.971984
# AV. FAMILY INCOME in hundreds (IC4)                                 1.000000
# PER CAPITA INCOME (IC5)                                             0.866662
# FOREIGN BORN (in %) (POBC1)                                         0.170932
# BORN IN STATE OF RESIDENCE in % (POBC2)                            -0.239296
# AVGGIFT                                                             0.136941
# DONOR TITLE CODE (TCODE)                                            0.007252
# AGE                                                                -0.003594
# DOMAIN_SOCIO-ECONOMIC-STATUS                                       -0.068788
# Unnamed: 20                                                              NaN
# Reference Date                                                           NaN
# 01.06.1997                                                               NaN
#
#                                          PER CAPITA INCOME (IC5)  \
# CONTROL NUMBER                                          0.106666
# HOME VALUE in % (HVP1) >= $200,000                      0.585630
# MEDIAN HOUSEHOLD INCOME (IC1)                           0.800237
# MEDIAN FAMILY INCOME in hundreds (IC2)                  0.872437
# AV. HOUSEHOLD INCOME in hundreds (IC3)                  0.824082
# AV. FAMILY INCOME in hundreds (IC4)                     0.866662
# PER CAPITA INCOME (IC5)                                 1.000000
# FOREIGN BORN (in %) (POBC1)                             0.159374
# BORN IN STATE OF RESIDENCE in % (POBC2)                -0.286556
# AVGGIFT                                                 0.144839
# DONOR TITLE CODE (TCODE)                                0.006903
# AGE                                                    -0.004413
# DOMAIN_SOCIO-ECONOMIC-STATUS                           -0.040051
# Unnamed: 20                                                  NaN
# Reference Date                                               NaN
# 01.06.1997                                                   NaN
#
#                                          FOREIGN BORN (in %) (POBC1)  \
# CONTROL NUMBER                                              0.182664
# HOME VALUE in % (HVP1) >= $200,000                          0.418266
# MEDIAN HOUSEHOLD INCOME (IC1)                               0.158926
# MEDIAN FAMILY INCOME in hundreds (IC2)                      0.158699
# AV. HOUSEHOLD INCOME in hundreds (IC3)                      0.179144
# AV. FAMILY INCOME in hundreds (IC4)                         0.170932
# PER CAPITA INCOME (IC5)                                     0.159374
# FOREIGN BORN (in %) (POBC1)                                 1.000000
# BORN IN STATE OF RESIDENCE in % (POBC2)                    -0.399192
# AVGGIFT                                                     0.069990
# DONOR TITLE CODE (TCODE)                                    0.017630
# AGE                                                        -0.011119
# DOMAIN_SOCIO-ECONOMIC-STATUS                               -0.126338
# Unnamed: 20                                                      NaN
# Reference Date                                                   NaN
# 01.06.1997                                                       NaN
#
#                                          BORN IN STATE OF RESIDENCE in % (POBC2)  \
# CONTROL NUMBER                                                         -0.124787
# HOME VALUE in % (HVP1) >= $200,000                                     -0.217391
# MEDIAN HOUSEHOLD INCOME (IC1)                                          -0.196077
# MEDIAN FAMILY INCOME in hundreds (IC2)                                 -0.212700
# AV. HOUSEHOLD INCOME in hundreds (IC3)                                 -0.227009
# AV. FAMILY INCOME in hundreds (IC4)                                    -0.239296
# PER CAPITA INCOME (IC5)                                                -0.286556
# FOREIGN BORN (in %) (POBC1)                                            -0.399192
# BORN IN STATE OF RESIDENCE in % (POBC2)                                 1.000000
# AVGGIFT                                                                -0.075349
# DONOR TITLE CODE (TCODE)                                                0.008626
# AGE                                                                    -0.000496
# DOMAIN_SOCIO-ECONOMIC-STATUS                                            0.089843
# Unnamed: 20                                                                  NaN
# Reference Date                                                               NaN
# 01.06.1997                                                                   NaN
#
#                                           AVGGIFT  DONOR TITLE CODE (TCODE)  \
# CONTROL NUMBER                           0.044976                  0.007538
# HOME VALUE in % (HVP1) >= $200,000       0.105605                 -0.014382
# MEDIAN HOUSEHOLD INCOME (IC1)            0.123165                  0.003085
# MEDIAN FAMILY INCOME in hundreds (IC2)   0.139765                  0.009813
# AV. HOUSEHOLD INCOME in hundreds (IC3)   0.129303                 -0.000968
# AV. FAMILY INCOME in hundreds (IC4)      0.136941                  0.007252
# PER CAPITA INCOME (IC5)                  0.144839                  0.006903
# FOREIGN BORN (in %) (POBC1)              0.069990                  0.017630
# BORN IN STATE OF RESIDENCE in % (POBC2) -0.075349                  0.008626
# AVGGIFT                                  1.000000                  0.037292
# DONOR TITLE CODE (TCODE)                 0.037292                  1.000000
# AGE                                      0.012288                  0.023610
# DOMAIN_SOCIO-ECONOMIC-STATUS            -0.041872                  0.028117
# Unnamed: 20                                   NaN                       NaN
# Reference Date                                NaN                       NaN
# 01.06.1997                                    NaN                       NaN
#
#                                               AGE  \
# CONTROL NUMBER                           0.032453
# HOME VALUE in % (HVP1) >= $200,000       0.028343
# MEDIAN HOUSEHOLD INCOME (IC1)           -0.002213
# MEDIAN FAMILY INCOME in hundreds (IC2)  -0.009438
# AV. HOUSEHOLD INCOME in hundreds (IC3)  -0.000989
# AV. FAMILY INCOME in hundreds (IC4)     -0.003594
# PER CAPITA INCOME (IC5)                 -0.004413
# FOREIGN BORN (in %) (POBC1)             -0.011119
# BORN IN STATE OF RESIDENCE in % (POBC2) -0.000496
# AVGGIFT                                  0.012288
# DONOR TITLE CODE (TCODE)                 0.023610
# AGE                                      1.000000
# DOMAIN_SOCIO-ECONOMIC-STATUS             0.096397
# Unnamed: 20                                   NaN
# Reference Date                                NaN
# 01.06.1997                                    NaN
#
#                                          DOMAIN_SOCIO-ECONOMIC-STATUS  \
# CONTROL NUMBER                                              -0.089187
# HOME VALUE in % (HVP1) >= $200,000                          -0.107111
# MEDIAN HOUSEHOLD INCOME (IC1)                               -0.078905
# MEDIAN FAMILY INCOME in hundreds (IC2)                      -0.066096
# AV. HOUSEHOLD INCOME in hundreds (IC3)                      -0.078070
# AV. FAMILY INCOME in hundreds (IC4)                         -0.068788
# PER CAPITA INCOME (IC5)                                     -0.040051
# FOREIGN BORN (in %) (POBC1)                                 -0.126338
# BORN IN STATE OF RESIDENCE in % (POBC2)                      0.089843
# AVGGIFT                                                     -0.041872
# DONOR TITLE CODE (TCODE)                                     0.028117
# AGE                                                          0.096397
# DOMAIN_SOCIO-ECONOMIC-STATUS                                 1.000000
# Unnamed: 20                                                       NaN
# Reference Date                                                    NaN
# 01.06.1997                                                        NaN
#
#                                          Unnamed: 20  Reference Date  \
# CONTROL NUMBER                                   NaN             NaN
# HOME VALUE in % (HVP1) >= $200,000               NaN             NaN
# MEDIAN HOUSEHOLD INCOME (IC1)                    NaN             NaN
# MEDIAN FAMILY INCOME in hundreds (IC2)           NaN             NaN
# AV. HOUSEHOLD INCOME in hundreds (IC3)           NaN             NaN
# AV. FAMILY INCOME in hundreds (IC4)              NaN             NaN
# PER CAPITA INCOME (IC5)                          NaN             NaN
# FOREIGN BORN (in %) (POBC1)                      NaN             NaN
# BORN IN STATE OF RESIDENCE in % (POBC2)          NaN             NaN
# AVGGIFT                                          NaN             NaN
# DONOR TITLE CODE (TCODE)                         NaN             NaN
# AGE                                              NaN             NaN
# DOMAIN_SOCIO-ECONOMIC-STATUS                     NaN             NaN
# Unnamed: 20                                      NaN             NaN
# Reference Date                                   NaN             NaN
# 01.06.1997                                       NaN             NaN
#
#                                          01.06.1997
# CONTROL NUMBER                                  NaN
# HOME VALUE in % (HVP1) >= $200,000              NaN
# MEDIAN HOUSEHOLD INCOME (IC1)                   NaN
# MEDIAN FAMILY INCOME in hundreds (IC2)          NaN
# AV. HOUSEHOLD INCOME in hundreds (IC3)          NaN
# AV. FAMILY INCOME in hundreds (IC4)             NaN
# PER CAPITA INCOME (IC5)                         NaN
# FOREIGN BORN (in %) (POBC1)                     NaN
# BORN IN STATE OF RESIDENCE in % (POBC2)         NaN
# AVGGIFT                                         NaN
# DONOR TITLE CODE (TCODE)                        NaN
# AGE                                             NaN
# DOMAIN_SOCIO-ECONOMIC-STATUS                    NaN
# Unnamed: 20                                     NaN
# Reference Date                                  NaN
# 01.06.1997                                      NaN

# %%
# plotting correlation heatmap
dataplot = sns.heatmap(numericals_2.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()

# %% [markdown]
# **Bonus: split Data set into train and test sets**

# %%
len(df1)
# Out:
# 9134

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size = 0.3)

# %%
len(train)
# Out:
# 7637

# %%
len(test)
# Out:
# 3273
