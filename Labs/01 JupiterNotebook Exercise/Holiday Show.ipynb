# %% [markdown]
# # Hello Holiday

# %% [markdown]
# ### What's the purpose?

# %% [markdown]
# This is a small insight in my fav holidays including some background information about the country.

# %%
def name_request():
    name = input("Your name: ")
    print("Here's a pic from", name,":")
    return
name_request()

# %% [markdown]
# ![Screenshot%202021-07-22%20at%2017.29.43.png](attachment:Screenshot%202021-07-22%20at%2017.29.43.png)

# %%
def preference():
    pref1 = input("Where is it located? ")
    pref2 = input("What's a traditional dish? ")
    pref3 = input("Name a secret attraction everyone should see? ")
    return
preference()

# %% [markdown]
# ![kotor-2-681x400.jpeg](attachment:kotor-2-681x400.jpeg)

# %% [markdown]
# ### Top 3 Things To Do:

# %% [markdown]
# - **Sunbathing** at the <span style='background: yellow'>*beach*</span>
# - **Hiking** in the <span style='color: brown'>*mountains*</span>
# - **Wondering around** in Kotor and <span style='color: blue'>**eat seafood**</span>

# %% [markdown]
# For more information watch this video[^1]

# %%
from IPython.display import Audio, Image, YouTubeVideo

id='WWn4lfNQy2s'
YouTubeVideo(id=id, width=560, height=315)

# %% [markdown]
# ### Footnotes:

# %%
[^1]: I used the IPython.display module.
